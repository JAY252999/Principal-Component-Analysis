# %%
#Importing all basic libraries
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import scipy
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale

# %%
#Reading data set
Data = pd.read_csv('wine.csv')
Data
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
#importing scale from sklearn for normalisation
from sklearn.preprocessing import scale

# %%
#normalizing data
Data_normal= scale(Data)
Data_normal
# Out:
# array([[-1.21394365,  1.51861254, -0.5622498 , ...,  0.36217728,
#          1.84791957,  1.01300893],
#        [-1.21394365,  0.24628963, -0.49941338, ...,  0.40605066,
#          1.1134493 ,  0.96524152],
#        [-1.21394365,  0.19687903,  0.02123125, ...,  0.31830389,
#          0.78858745,  1.39514818],
#        ...,
#        [ 1.37386437,  0.33275817,  1.74474449, ..., -1.61212515,
#         -1.48544548,  0.28057537],
#        [ 1.37386437,  0.20923168,  0.22769377, ..., -1.56825176,
#         -1.40069891,  0.29649784],
#        [ 1.37386437,  1.39508604,  1.58316512, ..., -1.52437837,
#         -1.42894777, -0.59516041]])

# %%
#importing PCA from sklearn.decomposition for feature engineering
from sklearn.decomposition import PCA

# %%
#using PCA and creating principal components
PCA_inprogress= PCA(n_components=14)
PCA_values = PCA_inprogress.fit_transform(Data_normal)
PCA_values
# Out:
# array([[-3.52293390e+00, -1.45309844e+00, -1.64795488e-01, ...,
#          5.52927766e-01, -3.02978176e-01,  2.00857450e-01],
#        [-2.52885806e+00,  3.30019252e-01, -2.02670665e+00, ...,
#          3.94971160e-01, -1.46645308e-01,  1.26402355e-01],
#        [-2.78502898e+00, -1.03693595e+00,  9.83237703e-01, ...,
#          1.89799314e-03,  2.12780166e-02, -5.57515155e-02],
#        ...,
#        [ 3.02727243e+00, -2.75604024e+00, -9.40803036e-01, ...,
#          6.93336340e-01,  1.67035660e-01, -3.16957430e-02],
#        [ 2.75522166e+00, -2.29378408e+00, -5.50473677e-01, ...,
#          3.44119826e-01, -1.09514873e-01,  1.02823104e-01],
#        [ 3.49633565e+00, -2.76060799e+00,  1.01315115e+00, ...,
#         -1.89866131e-01, -1.64090011e-01, -2.64916504e-01]])

# %%
#the amount of variance that each pca explain is
VAR = PCA_inprogress.explained_variance_ratio_
#cumulative variance
VAR = np.cumsum(np.round(VAR,decimals=4)*100)
VAR
# Out:
# array([ 39.54,  57.38,  67.71,  74.34,  80.61,  85.42,  89.38,  91.88,
#         93.98,  95.85,  97.46,  98.67,  99.6 , 100.01])

# %%
#variance plot for pca components obtained
plt.plot(VAR,color = "red")

# %%
#creating final data for analysis by considering first two PC's
PCA = pd.concat([pd.DataFrame(PCA_values[:,0:2],columns=['PC1','PC2']), Data[['Type']]], axis = 1)
PCA
# Out:
#           PC1       PC2  Type
# 0   -3.522934 -1.453098     1
# 1   -2.528858  0.330019     1
# 2   -2.785029 -1.036936     1
# 3   -3.922588 -2.768210     1
# 4   -1.407511 -0.867773     1
# ..        ...       ...   ...
# 173  3.627996 -2.206617     3
# 174  2.942729 -1.752263     3
# 175  3.027272 -2.756040     3
# 176  2.755222 -2.293784     3
# 177  3.496336 -2.760608     3
#
# [178 rows x 3 columns]

# %%
plt.style.use('classic')
PCA_1= sns.scatterplot(data=PCA,x='PC1',y='PC2',s = 100)

# %% [markdown]
# # H-Clustering

# %%
#reading data for hierarchial clustering
Data = pd.read_csv('wine.csv')
Data
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
#ploting dendrogram for hierarchial clustering
from scipy.cluster.hierarchy import linkage 
import scipy.cluster.hierarchy as sch 
z = linkage(PCA, method="average",metric="euclidean")
plt.figure(figsize=(15, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
sch.dendrogram(z)
plt.show()

# %%
#adding cluster labers to dataframe
from sklearn.cluster import AgglomerativeClustering 
h_complete = AgglomerativeClustering(n_clusters=3, linkage='average',affinity = "euclidean").fit(PCA) 
cluster_labels=pd.Series(h_complete.labels_)
cluster_labels
Data['clust']=cluster_labels # creating a  new column and assigning it to new column 
Data
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %% [markdown]
# # Exploring clusters

# %%
Data.groupby(Data.clust).mean()
# Out:
#            Type    Alcohol     Malic       Ash  Alcalinity   Magnesium  \
# clust
# 0      2.979592  13.151633  3.344490  2.434694   21.438776   99.020408
# 1      1.048387  13.676774  1.997903  2.466290   17.462903  107.967742
# 2      2.000000  12.264478  1.912239  2.224328   19.953731   92.656716
#
#         Phenols  Flavanoids  Nonflavanoids  Proanthocyanins     Color  \
# clust
# 0      1.678163    0.797959       0.450816         1.163061  7.343265
# 1      2.847581    3.003226       0.292097         1.922097  5.453548
# 2      2.235075    2.028507       0.361343         1.597313  3.020896
#
#             Hue  Dilution      Proline
# clust
# 0      0.685918  1.690204   627.551020
# 1      1.065484  3.163387  1100.225806
# 2      1.056060  2.775075   507.208955

# %%
Data_clust1 = Data[(Data.clust==0)]
Data_clust1
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 83      2    13.05   3.86  2.32        22.5         85     1.65        1.59
# 130     3    12.86   1.35  2.32        18.0        122     1.51        1.25
# 131     3    12.88   2.99  2.40        20.0        104     1.30        1.22
# 132     3    12.81   2.31  2.40        24.0         98     1.15        1.09
# 133     3    12.70   3.55  2.36        21.5        106     1.70        1.20
# 134     3    12.51   1.24  2.25        17.5         85     2.00        0.58
# 135     3    12.60   2.46  2.20        18.5         94     1.62        0.66
# 136     3    12.25   4.72  2.54        21.0         89     1.38        0.47
# 137     3    12.53   5.51  2.64        25.0         96     1.79        0.60
# 138     3    13.49   3.59  2.19        19.5         88     1.62        0.48
# 139     3    12.84   2.96  2.61        24.0        101     2.32        0.60
# ...

# %%
Data_clust2 = Data[(Data.clust==1)]
Data_clust2
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 57      1    13.29   1.97  2.68        16.8        102     3.00        3.23
# 58      1    13.72   1.43  2.50        16.7        108     3.40        3.67
# 73      2    12.99   1.67  2.60        30.0        139     3.30        2.89
# 95      2    12.47   1.52  2.20        19.0        162     2.50        2.27
# 121     2    11.56   2.05  3.23        28.5        119     3.18        5.08
#
# ...

# %%
Data_clust3 = Data[(Data.clust==2)]
Data_clust3
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 59      2    12.37   0.94  1.36        10.6         88     1.98        0.57
# 60      2    12.33   1.10  2.28        16.0        101     2.05        1.09
# 61      2    12.64   1.36  2.02        16.8        100     2.02        1.41
# 62      2    13.67   1.25  1.92        18.0         94     2.10        1.79
# 63      2    12.37   1.13  2.16        19.0         87     3.50        3.10
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 125     2    12.07   2.16  2.17        21.0         85     2.60        2.65
# 126     2    12.43   1.53  2.29        21.5         86     2.74        3.15
# 127     2    11.79   2.13  2.78        28.5         92     2.13        2.24
# 128     2    12.37   1.63  2.30        24.5         88     2.22        2.45
# 129     2    12.04   4.30  2.38        22.0         80     2.10        1.75
#
# ...

# %%
#creating barplot for the clusters 

fig, ax = plt.subplots(figsize=(10, 6))
Data.groupby(['clust']).count()['Type'].plot(kind='bar')
plt.ylabel('customers')
plt.title('Hierarchical Clustering',fontsize='large',fontweight='bold')
ax.set_xlabel('Clusters', fontsize='large', fontweight='bold')
ax.set_ylabel('ID counts', fontsize='large', fontweight='bold')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2')])

# %% [markdown]
# # KMeans Clustering

# %%
#importing libraries for KMeans clustering
from sklearn.cluster import KMeans

# %%
#Ploting elbow curve for optimised number of clusters

from sklearn.cluster import KMeans
fig = plt.figure(figsize=(10, 8))
WCSS = []
for i in range(1, 11):
    clf = KMeans(n_clusters=i)
    clf.fit(PCA)
    WCSS.append(clf.inertia_) # inertia is another name for WCSS
plt.plot(range(1, 11), WCSS)
plt.title('The Elbow Method')
plt.ylabel('WCSS')
plt.xlabel('Number of Clusters')
plt.show()

# %%
#making 3 clusters as per elbow curve insights
clf = KMeans(n_clusters=3)
y_kmeans = clf.fit_predict(PCA)

# %%
#re reading data for KMeans clustering
Data = pd.read_csv('wine.csv')
Data
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %%
#adding cluster labels to dataframe
md = pd.Series(y_kmeans)
Data['clust'] = md
Data
# Out:
#      Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0       1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1       1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2       1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3       1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4       1    13.24   2.59  2.87        21.0        118     2.80        2.69
# ..    ...      ...    ...   ...         ...        ...      ...         ...
# 173     3    13.71   5.65  2.45        20.5         95     1.68        0.61
# 174     3    13.40   3.91  2.48        23.0        102     1.80        0.75
# 175     3    13.27   4.28  2.26        20.0        120     1.59        0.69
# 176     3    13.17   2.59  2.37        20.0        120     1.65        0.68
# 177     3    14.13   4.10  2.74        24.5         96     2.05        0.76
#
# ...

# %% [markdown]
# # Exploring clusters

# %%
Data.iloc[:,1:].groupby(Data.clust).mean()
# Out:
#          Alcohol     Malic       Ash  Alcalinity   Magnesium   Phenols  \
# clust
# 0      12.264478  1.912239  2.224328   19.953731   92.656716  2.235075
# 1      13.676774  1.997903  2.466290   17.462903  107.967742  2.847581
# 2      13.151633  3.344490  2.434694   21.438776   99.020408  1.678163
#
#        Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  \
# clust
# 0        2.028507       0.361343         1.597313  3.020896  1.056060
# 1        3.003226       0.292097         1.922097  5.453548  1.065484
# 2        0.797959       0.450816         1.163061  7.343265  0.685918
#
#        Dilution      Proline  clust
# clust
# 0      2.775075   507.208955    0.0
# 1      3.163387  1100.225806    1.0
# 2      1.690204   627.551020    2.0

# %%
Data.plot(x="Alcohol",y ="Malic",c=clf.labels_,kind="scatter",s=30 ,cmap=plt.cm.coolwarm) 
plt.title('Clusters using KMeans')
# Out:
# Text(0.5, 1.0, 'Clusters using KMeans')

# %%
#creating barplot for the clusters 

fig, ax = plt.subplots(figsize=(10, 6))
Data.groupby(['clust']).count()['Type'].plot(kind='bar')
plt.ylabel('customers')
plt.title('Hierarchical Clustering',fontsize='large',fontweight='bold')
ax.set_xlabel('Clusters', fontsize='large', fontweight='bold')
ax.set_ylabel('ID counts', fontsize='large', fontweight='bold')
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
# Out:
# (array([0, 1, 2]), [Text(0, 0, '0'), Text(1, 0, '1'), Text(2, 0, '2')])

# %%
WCSS
# Out:
# [1536.1985476484288,
#  708.6007216041805,
#  240.31193567706094,
#  187.24121119137484,
#  150.8725365669171,
#  116.62678540738375,
#  94.70504000277224,
#  85.53222971109712,
#  78.39326574172429,
#  70.37389202998685]
